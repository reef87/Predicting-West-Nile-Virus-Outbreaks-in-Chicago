# %% [markdown]
# ### In this competition, you will be analyzing weather data and GIS data and predicting whether or not West Nile virus is present, for a given _time_, _location_, and _species_.

# %% [markdown]
# #### Questions
#
# - Do we have spray data from just two years 2011 and 2013, yes! , is 2011 when city started to spray?
# - How does spraying impact wnv presence?
#
# - Let's looking at training data by year

# %%
import pandas as pd
import numpy as np
import geopy as gp
from geopy.geocoders import Nominatim
from geopy.distance import vincenty

# %%
geolocator = Nominatim()
location = geolocator.geocode("175 5th Avenue NYC")
print(location)
# Out:
# Flatiron Building, 175, 5th Avenue, Flatiron Building, Manhattan Community Board 5, New York County, NYC, New York, 10010, United States of America

# %% [markdown]
# #### Read in csv data files

# %%
train = pd.read_csv('./assets/train.csv')
#test = pd.read_csv('./assets/test.csv')
spray = pd.read_csv('./assets/spray.csv')
weather = pd.read_csv('./assets/weather.csv')

print(train.shape)
print(spray.shape)
print(weather.shape)
# Out:
# (10506, 12)
# (14835, 4)
# (2944, 22)

# %% [markdown]
# ### Spray Data

# %%
spray.head()
# Out:
#         Date        Time   Latitude  Longitude  Day  Month  Year
# 0 2011-08-29  6:56:58 PM  42.391623 -88.089163   29      8  2011
# 1 2011-08-29  6:57:08 PM  42.391348 -88.089163   29      8  2011
# 2 2011-08-29  6:57:18 PM  42.391022 -88.089157   29      8  2011
# 3 2011-08-29  6:57:28 PM  42.390637 -88.089158   29      8  2011
# 4 2011-08-29  6:57:38 PM  42.390410 -88.088858   29      8  2011

# %%
spray.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14835 entries, 0 to 14834
# Data columns (total 4 columns):
# Date         14835 non-null datetime64[ns]
# Time         14835 non-null object
# Latitude     14835 non-null float64
# Longitude    14835 non-null float64
# dtypes: datetime64[ns](1), float64(2), object(1)
# memory usage: 463.7+ KB

# %%
# Fill in empty times with zero for now (not sure the exact spray time will come into play)
spray['Time'].fillna(0, inplace=True)

# %%
# Convert Date to datetime and break apart
spray['Date'] = pd.to_datetime(spray['Date'])
spray['Year'] = spray['Date'].apply(lambda x: x.year)
spray['Month'] = spray['Date'].apply(lambda x: x.month)
spray['Day'] = spray['Date'].apply(lambda x: x.day)

# %%
spray['Date'].value_counts()
# Out:
# 2013-08-15    2668
# 2013-08-29    2302
# 2013-07-17    2202
# 2011-09-07    2114
# 2013-07-25    1607
# 2013-08-22    1587
# 2013-08-08    1195
# 2013-09-05     924
# 2013-08-16     141
# 2011-08-29      95
# Name: Date, dtype: int64

# %% [markdown]
# #### Are the spray coordinates unique for each observations or are the same coordinates being sprayed more than once?
#
# ** !! There is some bad data, one location that shows up 541 time for the same Date and Time and another show up twice. This not correct,  Same date might be okay, but same Date and Time is questionable.**

# %%
df_spray = pd.DataFrame({'count' : spray.groupby(['Date','Latitude','Longitude','Time', 'Year', 'Month']).size()}).reset_index()
df_spray.sort_values('count', ascending=False).head(10)
# Note look at results, we have one location that show up 541 time for the same Date and Time?
# Out:
#            Date   Latitude  Longitude         Time  Year  Month  count
# 1208 2011-09-07  41.986460 -87.794225   7:44:32 PM  2011      9    541
# 1035 2011-09-07  41.983917 -87.793088   7:43:40 PM  2011      9      2
# 0    2011-08-29  42.389460 -88.093895   7:11:28 PM  2011      8      1
# 9523 2013-08-22  41.716443 -87.615177  11:38:46 PM  2013      8      1
# 9524 2013-08-22  41.716572 -87.594697   8:18:20 PM  2013      8      1
# 9525 2013-08-22  41.716612 -87.616337  11:37:06 PM  2013      8      1
# 9526 2013-08-22  41.716637 -87.600332   8:21:20 PM  2013      8      1
# 9527 2013-08-22  41.716650 -87.599487   8:21:10 PM  2013      8      1
# 9528 2013-08-22  41.716668 -87.598808   8:21:00 PM  2013      8      1
# 9529 2013-08-22  41.716687 -87.598012   8:20:50 PM  2013      8      1

# %% [markdown]
# ### Training Data for Mosquito testing

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10506 entries, 0 to 10505
# Data columns (total 12 columns):
# Date                      10506 non-null object
# Address                   10506 non-null object
# Species                   10506 non-null object
# Block                     10506 non-null int64
# Street                    10506 non-null object
# Trap                      10506 non-null object
# AddressNumberAndStreet    10506 non-null object
# Latitude                  10506 non-null float64
# Longitude                 10506 non-null float64
# AddressAccuracy           10506 non-null int64
# NumMosquitos              10506 non-null int64
# WnvPresent                10506 non-null int64
# dtypes: float64(2), int64(4), object(6)
# memory usage: 985.0+ KB

# %%
train.describe()
# Out:
#               Block      Latitude     Longitude  AddressAccuracy  \
# count  10506.000000  10506.000000  10506.000000     10506.000000
# mean      35.687797     41.841139    -87.699908         7.819532
# std       24.339468      0.112742      0.096514         1.452921
# min       10.000000     41.644612    -87.930995         3.000000
# 25%       12.000000     41.732984    -87.760070         8.000000
# 50%       33.000000     41.846283    -87.694991         8.000000
# 75%       52.000000     41.954690    -87.627796         9.000000
# max       98.000000     42.017430    -87.531635         9.000000
#
#        NumMosquitos    WnvPresent
# count  10506.000000  10506.000000
# mean      12.853512      0.052446
# std       16.133816      0.222936
# min        1.000000      0.000000
# 25%        2.000000      0.000000
# 50%        5.000000      0.000000
# 75%       17.000000      0.000000
# max       50.000000      1.000000

# %%
# Lets convert date from object to datetime.
train['Date'] = pd.to_datetime(train['Date'])
train['Year'] = train['Date'].apply(lambda x: x.year)
train['Month'] = train['Date'].apply(lambda x: x.month)
train['Day'] = train['Date'].apply(lambda x: x.day)

# %%
train['Species'].value_counts()
# Out:
# CULEX PIPIENS/RESTUANS    4752
# CULEX RESTUANS            2740
# CULEX PIPIENS             2699
# CULEX TERRITANS            222
# CULEX SALINARIUS            86
# CULEX TARSALIS               6
# CULEX ERRATICUS              1
# Name: Species, dtype: int64

# %%
len(train['Trap'].value_counts())
# Out:
# 136

# %%
train['NumMosquitos'].value_counts()
# Out:
# 1     2307
# 2     1300
# 50    1019
# 3      896
# 4      593
# 5      489
# 6      398
# 7      326
# 8      244
# 9      237
# 10     206
# 11     170
# 13     163
# 12     132
# 16     128
# 14     120
# 15     112
# 17     107
# 18      92
# 19      86
# 21      85
# 20      79
# 23      69
# 27      67
# 37      61
# 26      57
# 24      57
# 22      56
# 25      50
# 39      49
# 29      48
# 36      47
# 31      47
# 30      44
# 35      43
# 28      43
# 46      43
# 43      39
# 32      39
# 47      37
# 33      36
# 48      36
# 49      35
# 45      35
# 38      35
# 34      31
# 41      31
# 42      29
# 40      28
# 44      25
# Name: NumMosquitos, dtype: int64

# %%
train[train['NumMosquitos'] >=45]
# Out:
#             Date                                            Address  \
# 293   2007-07-11     2200 West 113th Street, Chicago, IL 60643, USA
# 295   2007-07-11     2200 West 113th Street, Chicago, IL 60643, USA
# 350   2007-07-11     3500 West 116th Street, Chicago, IL 60655, USA
# 351   2007-07-11     3500 West 116th Street, Chicago, IL 60655, USA
# 353   2007-07-11     3500 West 116th Street, Chicago, IL 60655, USA
# 529   2007-07-18                South Doty Avenue, Chicago, IL, USA
# 530   2007-07-18        South Stony Island Avenue, Chicago, IL, USA
# 531   2007-07-18        South Stony Island Avenue, Chicago, IL, USA
# 533   2007-07-18        South Stony Island Avenue, Chicago, IL, USA
# 547   2007-07-18          3700 118th Street, Chicago, IL 60617, USA
# 548   2007-07-18          3700 118th Street, Chicago, IL 60617, USA
# 553   2007-07-18     3800 East 115th Street, Chicago, IL 60617, USA
# 572   2007-07-19        South Stony Island Avenue, Chicago, IL, USA
# 586   2007-07-19          3700 118th Street, Chicago, IL 60617, USA
# 587   2007-07-19          3700 118th Street, Chicago, IL 60617, USA
# 588   2007-07-19          3700 118th Street, Chicago, IL 60617, USA
# 589   2007-07-19          3700 118th Street, Chicago, IL 60617, USA
# 590   2007-07-19          3700 118th Street, Chicago, IL 60617, USA
# 591   2007-07-19          3700 118th Street, Chicago, IL 60617, USA
# 592   2007-07-19          3700 118th Street, Chicago, IL 60617, USA
# 593   2007-07-19          3700 118th Street, Chicago, IL 60617, USA
# 601   2007-07-25                South Doty Avenue, Chicago, IL, USA
# 602   2007-07-25                South Doty Avenue, Chicago, IL, USA
# 603   2007-07-25                South Doty Avenue, Chicago, IL, USA
# 604   2007-07-25                South Doty Avenue, Chicago, IL, USA
# 605   2007-07-25                South Doty Avenue, Chicago, IL, USA
# 606   2007-07-25                South Doty Avenue, Chicago, IL, USA
# 607   2007-07-25                South Doty Avenue, Chicago, IL, USA
# 608   2007-07-25                South Doty Avenue, Chicago, IL, USA
# 609   2007-07-25                South Doty Avenue, Chicago, IL, USA
# ...          ...                                                ...
# 9988  2013-08-29  ORD Terminal 5, O'Hare International Airport, ...
# 9989  2013-08-29  ORD Terminal 5, O'Hare International Airport, ...
# 9992  2013-08-29  ORD Terminal 5, O'Hare International Airport, ...
# 10011 2013-08-29   7100 North Harlem Avenue, Chicago, IL 60631, USA
# 
# 10098                8            50           0      9  2013    6
# 10118                9            50           0      9  2013    6
# 10122                9            50           1      9  2013    6
# 10124                9            50           1      9  2013    6
# 10175                8            46           0      9  2013   12
# 10183                9            45           1      9  2013   12
# 10211                9            45           0      9  2013   12
# 10239                5            47           1      9  2013   12
# 10240                5            50           1      9  2013   12
# 10242                5            50           0      9  2013   12
# 10259                9            50           0      9  2013   12
# 10262                9            50           0      9  2013   12
# 10267                9            50           0      9  2013   12
# 10270                9            46           0      9  2013   12
# 10276                8            47           1      9  2013   12
# 10282                9            45           0      9  2013   12
#
#        spray_date          spray_date2  \
# 293           NaN                    0
# 295           NaN                    0
# 350           NaN                    0
# 351           NaN                    0
# 353           NaN                    0
# 529           NaN                    0
# 530           NaN                    0
# 531           NaN                    0
# 533           NaN                    0
# 547           NaN                    0
# 548           NaN                    0
# 553           NaN                    0
# 572           NaN                    0
# 586           NaN                    0
# 587           NaN                    0
# 588           NaN                    0
# 589           NaN                    0
# 590           NaN                    0
# 591           NaN                    0
# 592           NaN                    0
# 593           NaN                    0
# 601           NaN                    0
# 602           NaN                    0
# 603           NaN                    0
# 604           NaN                    0
# 605           NaN                    0
# 606           NaN                    0
# 607           NaN                    0
# 608           NaN                    0
# 609           NaN                    0
# ...           ...                  ...
# 9988          NaN  2013-07-17 00:00:00
# 9989          NaN  2013-07-17 00:00:00
# 9992          NaN  2013-07-17 00:00:00
# 10011         NaN  2013-07-17 00:00:00
# 10012         NaN  2013-07-17 00:00:00
# 10013         NaN  2013-07-17 00:00:00
# 10014         NaN  2013-07-17 00:00:00
# 10020         NaN  2013-08-15 00:00:00
# 10029         NaN  2013-07-17 00:00:00
# 10031         NaN  2013-07-17 00:00:00
# 10036         NaN  2013-07-17 00:00:00
# 10044         NaN  2013-08-08 00:00:00
# 10058         NaN  2013-07-25 00:00:00
# 10071         NaN  2013-08-22 00:00:00
# 10098         NaN  2013-08-29 00:00:00
# 10118         NaN  2013-07-17 00:00:00
# 10122         NaN  2013-07-17 00:00:00
# 10124         NaN  2013-07-17 00:00:00
# 10175         NaN  2013-07-17 00:00:00
# 10183         NaN  2013-08-29 00:00:00
# 10211         NaN  2013-08-22 00:00:00
# 10239         NaN  2013-08-29 00:00:00
# 10240         NaN  2013-08-29 00:00:00
# 10242         NaN  2013-08-29 00:00:00
# 10259         NaN  2013-07-17 00:00:00
# 10262         NaN  2013-07-17 00:00:00
# 10267         NaN  2013-07-17 00:00:00
# 10270         NaN  2013-07-17 00:00:00
# 10276         NaN  2013-08-29 00:00:00
# 10282         NaN  2013-08-15 00:00:00
#
#                                                 JustDate
# 293    <built-in method date of Timestamp object at 0...
# 295    <built-in method date of Timestamp object at 0...
# 350    <built-in method date of Timestamp object at 0...
# 351    <built-in method date of Timestamp object at 0...
# 353    <built-in method date of Timestamp object at 0...
# 529    <built-in method date of Timestamp object at 0...
# 530    <built-in method date of Timestamp object at 0...
# 531    <built-in method date of Timestamp object at 0...
# 533    <built-in method date of Timestamp object at 0...
# 547    <built-in method date of Timestamp object at 0...
# 548    <built-in method date of Timestamp object at 0...
# 553    <built-in method date of Timestamp object at 0...
# 572    <built-in method date of Timestamp object at 0...
# 586    <built-in method date of Timestamp object at 0...
# 587    <built-in method date of Timestamp object at 0...
# 588    <built-in method date of Timestamp object at 0...
# 589    <built-in method date of Timestamp object at 0...
# 590    <built-in method date of Timestamp object at 0...
# 591    <built-in method date of Timestamp object at 0...
# 592    <built-in method date of Timestamp object at 0...
# 593    <built-in method date of Timestamp object at 0...
# 601    <built-in method date of Timestamp object at 0...
# 602    <built-in method date of Timestamp object at 0...
# 603    <built-in method date of Timestamp object at 0...
# 604    <built-in method date of Timestamp object at 0...
# 605    <built-in method date of Timestamp object at 0...
# 606    <built-in method date of Timestamp object at 0...
# 607    <built-in method date of Timestamp object at 0...
# 608    <built-in method date of Timestamp object at 0...
# 609    <built-in method date of Timestamp object at 0...
# ...                                                  ...
# 9988   <built-in method date of Timestamp object at 0...
# 9989   <built-in method date of Timestamp object at 0...
# 9992   <built-in method date of Timestamp object at 0...
# 10011  <built-in method date of Timestamp object at 0...
# 10012  <built-in method date of Timestamp object at 0...
# 10013  <built-in method date of Timestamp object at 0...
# 10014  <built-in method date of Timestamp object at 0...
# 10020  <built-in method date of Timestamp object at 0...
# 10029  <built-in method date of Timestamp object at 0...
# 10031  <built-in method date of Timestamp object at 0...
# 10036  <built-in method date of Timestamp object at 0...
# 10044  <built-in method date of Timestamp object at 0...
# 10058  <built-in method date of Timestamp object at 0...
# 10071  <built-in method date of Timestamp object at 0...
# 10098  <built-in method date of Timestamp object at 0...
# 10118  <built-in method date of Timestamp object at 0...
# 10122  <built-in method date of Timestamp object at 0...
# 10124  <built-in method date of Timestamp object at 0...
# 10175  <built-in method date of Timestamp object at 0...
# 10183  <built-in method date of Timestamp object at 0...
# 10211  <built-in method date of Timestamp object at 0...
# 10239  <built-in method date of Timestamp object at 0...
# 10240  <built-in method date of Timestamp object at 0...
# 10242  <built-in method date of Timestamp object at 0...
# 10259  <built-in method date of Timestamp object at 0...
# 10262  <built-in method date of Timestamp object at 0...
# 10267  <built-in method date of Timestamp object at 0...
# 10270  <built-in method date of Timestamp object at 0...
# 10276  <built-in method date of Timestamp object at 0...
# 10282  <built-in method date of Timestamp object at 0...
#
# [1205 rows x 18 columns]

# %%
pd.DataFrame(train[(train['Trap'] == 'T900') & (train['Year'] == 2013) & (train['Month'] == 9)]).reset_index()
# Out:
#     index       Date                                            Address  \
# 0   10118 2013-09-06  ORD Terminal 5, O'Hare International Airport, ...
# 1   10119 2013-09-06  ORD Terminal 5, O'Hare International Airport, ...
# 2   10120 2013-09-06  ORD Terminal 5, O'Hare International Airport, ...
# 3   10121 2013-09-06  ORD Terminal 5, O'Hare International Airport, ...
# 4   10122 2013-09-06  ORD Terminal 5, O'Hare International Airport, ...
# 5   10123 2013-09-06  ORD Terminal 5, O'Hare International Airport, ...
# 6   10124 2013-09-06  ORD Terminal 5, O'Hare International Airport, ...
# 7   10125 2013-09-06  ORD Terminal 5, O'Hare International Airport, ...
# 8   10126 2013-09-06  ORD Terminal 5, O'Hare International Airport, ...
# 9   10127 2013-09-06  ORD Terminal 5, O'Hare International Airport, ...
# 10  10128 2013-09-06  ORD Terminal 5, O'Hare International Airport, ...
# 11  10129 2013-09-06  ORD Terminal 5, O'Hare International Airport, ...
# 12  10130 2013-09-06  ORD Terminal 5, O'Hare International Airport, ...
# 13  10131 2013-09-06  ORD Terminal 5, O'Hare International Airport, ...
# 14  10132 2013-09-06  ORD Terminal 5, O'Hare International Airport, ...
# 15  10133 2013-09-06  ORD Terminal 5, O'Hare International Airport, ...
# 16  10134 2013-09-06  ORD Terminal 5, O'Hare International Airport, ...
# 17  10135 2013-09-06  ORD Terminal 5, O'Hare International Airport, ...
# 18  10256 2013-09-12  ORD Terminal 5, O'Hare International Airport, ...
# 19  10257 2013-09-12  ORD Terminal 5, O'Hare International Airport, ...
# 20  10258 2013-09-12  ORD Terminal 5, O'Hare International Airport, ...
# 21  10259 2013-09-12  ORD Terminal 5, O'Hare International Airport, ...
# 22  10260 2013-09-12  ORD Terminal 5, O'Hare International Airport, ...
# 23  10261 2013-09-12  ORD Terminal 5, O'Hare International Airport, ...
# 24  10262 2013-09-12  ORD Terminal 5, O'Hare International Airport, ...
# 25  10263 2013-09-12  ORD Terminal 5, O'Hare International Airport, ...
# 26  10264 2013-09-12  ORD Terminal 5, O'Hare International Airport, ...
# 27  10265 2013-09-12  ORD Terminal 5, O'Hare International Airport, ...
# 28  10266 2013-09-12  ORD Terminal 5, O'Hare International Airport, ...
# 29  10267 2013-09-12  ORD Terminal 5, O'Hare International Airport, ...
# 30  10268 2013-09-12  ORD Terminal 5, O'Hare International Airport, ...
# 31  10269 2013-09-12  ORD Terminal 5, O'Hare International Airport, ...
# 32  10270 2013-09-12  ORD Terminal 5, O'Hare International Airport, ...
# 33  10386 2013-09-19  ORD Terminal 5, O'Hare International Airport, ...
# 34  10387 2013-09-19  ORD Terminal 5, O'Hare International Airport, ...
# 35  10388 2013-09-19  ORD Terminal 5, O'Hare International Airport, ...
# 36  10389 2013-09-19  ORD Terminal 5, O'Hare International Airport, ...
# 37  10390 2013-09-19  ORD Terminal 5, O'Hare International Airport, ...
# 38  10391 2013-09-19  ORD Terminal 5, O'Hare International Airport, ...
# 39  10392 2013-09-19  ORD Terminal 5, O'Hare International Airport, ...
# 40  10484 2013-09-26  ORD Terminal 5, O'Hare International Airport, ...
# 41  10485 2013-09-26  ORD Terminal 5, O'Hare International Airport, ...
# 42  10486 2013-09-26  ORD Terminal 5, O'Hare International Airport, ...
# 43  10487 2013-09-26  ORD Terminal 5, O'Hare International Airport, ...
# 44  10488 2013-09-26  ORD Terminal 5, O'Hare International Airport, ...
# 45  10489 2013-09-26  ORD Terminal 5, O'Hare International Airport, ...
#
#                    Species  Block            Street  Trap  \
# 0   CULEX PIPIENS/RESTUANS     10   W OHARE AIRPORT  T900
# 1   CULEX PIPIENS/RESTUANS     10   W OHARE AIRPORT  T900
# 2   CULEX PIPIENS/RESTUANS     10   W OHARE AIRPORT  T900
# 3   CULEX PIPIENS/RESTUANS     10   W OHARE AIRPORT  T900
# 4   CULEX PIPIENS/RESTUANS     10   W OHARE AIRPORT  T900
# 5   CULEX PIPIENS/RESTUANS     10   W OHARE AIRPORT  T900
# 6   CULEX PIPIENS/RESTUANS     10   W OHARE AIRPORT  T900
# 7           CULEX RESTUANS     10   W OHARE AIRPORT  T900
# 8           CULEX RESTUANS     10   W OHARE AIRPORT  T900
# 9            CULEX PIPIENS     10   W OHARE AIRPORT  T900
# 10           CULEX PIPIENS     10   W OHARE AIRPORT  T900
# 11           CULEX PIPIENS     10   W OHARE AIRPORT  T900
# 12           CULEX PIPIENS     10   W OHARE AIRPORT  T900
# 13           CULEX PIPIENS     10   W OHARE AIRPORT  T900
# 14           CULEX PIPIENS     10   W OHARE AIRPORT  T900
# 15           CULEX PIPIENS     10   W OHARE AIRPORT  T900
# 16           CULEX PIPIENS     10   W OHARE AIRPORT  T900
# 17         CULEX ERRATICUS     10   W OHARE AIRPORT  T900
# 18  CULEX PIPIENS/RESTUANS     10   W OHARE AIRPORT  T900
# 19  CULEX PIPIENS/RESTUANS     10   W OHARE AIRPORT  T900
# 20  CULEX PIPIENS/RESTUANS     10   W OHARE AIRPORT  T900
# 21  CULEX PIPIENS/RESTUANS     10   W OHARE AIRPORT  T900
# 22  CULEX PIPIENS/RESTUANS     10   W OHARE AIRPORT  T900
# 23  CULEX PIPIENS/RESTUANS     10   W OHARE AIRPORT  T900
# 24  CULEX PIPIENS/RESTUANS     10   W OHARE AIRPORT  T900
# 25          CULEX RESTUANS     10   W OHARE AIRPORT  T900
# 26           CULEX PIPIENS     10   W OHARE AIRPORT  T900
# 27           CULEX PIPIENS     10   W OHARE AIRPORT  T900
# 28           CULEX PIPIENS     10   W OHARE AIRPORT  T900
# 29           CULEX PIPIENS     10   W OHARE AIRPORT  T900
# 30           CULEX PIPIENS     10   W OHARE AIRPORT  T900
# 31           CULEX PIPIENS     10   W OHARE AIRPORT  T900
# 32           CULEX PIPIENS     10   W OHARE AIRPORT  T900
# 33  CULEX PIPIENS/RESTUANS     10   W OHARE AIRPORT  T900
# 34  CULEX PIPIENS/RESTUANS     10   W OHARE AIRPORT  T900
# 35  CULEX PIPIENS/RESTUANS     10   W OHARE AIRPORT  T900
# 36           CULEX PIPIENS     10   W OHARE AIRPORT  T900
# 37           CULEX PIPIENS     10   W OHARE AIRPORT  T900
# 38           CULEX PIPIENS     10   W OHARE AIRPORT  T900
# 39           CULEX PIPIENS     10   W OHARE AIRPORT  T900
# 40  CULEX PIPIENS/RESTUANS     10   W OHARE AIRPORT  T900
# 41  CULEX PIPIENS/RESTUANS     10   W OHARE AIRPORT  T900
# 42           CULEX PIPIENS     10   W OHARE AIRPORT  T900
# 43           CULEX PIPIENS     10   W OHARE AIRPORT  T900
# 44           CULEX PIPIENS     10   W OHARE AIRPORT  T900
# 45           CULEX PIPIENS     10   W OHARE AIRPORT  T900
#
#                 AddressNumberAndStreet   Latitude  Longitude  AddressAccuracy  \
# 0   1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615                9
# 1   1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615                9
# 2   1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615                9
# 3   1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615                9
# 4   1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615                9
# 5   1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615                9
# 6   1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615                9
# 7   1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615                9
# 8   1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615                9
# 9   1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615                9
# 10  1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615                9
# 11  1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615                9
# 12  1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615                9
# 13  1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615                9
# 14  1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615                9
# 15  1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615                9
# 16  1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615                9
# 17  1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615                9
# 18  1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615                9
# 19  1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615                9
# 20  1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615                9
# 21  1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615                9
# 22  1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615                9
# 23  1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615                9
# 24  1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615                9
# 25  1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615                9
# 26  1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615                9
# 27  1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615                9
# 28  1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615                9
# 29  1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615                9
# 30  1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615                9
# 31  1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615                9
# 32  1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615                9
# 33  1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615                9
# 34  1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615                9
# 35  1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615                9
# 36  1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615                9
# 37  1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615                9
# 38  1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615                9
# 39  1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615                9
# 40  1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615                9
# 41  1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615                9
# 42  1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615                9
# 43  1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615                9
# 44  1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615                9
# 45  1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615                9
#
#     NumMosquitos  WnvPresent  Month  Year  Day  spray_date  \
# 0             50           0      9  2013    6         NaN
# 1             44           1      9  2013    6         NaN
# 2             39           1      9  2013    6         NaN
# 3             38           1      9  2013    6         NaN
# 4             50           1      9  2013    6         NaN
# 5             37           0      9  2013    6         NaN
# 6             50           1      9  2013    6         NaN
# 7             26           0      9  2013    6         NaN
# 8             14           1      9  2013    6         NaN
# 9             23           1      9  2013    6         NaN
# 10            41           0      9  2013    6         NaN
# 11            34           0      9  2013    6         NaN
# 12             4           0      9  2013    6         NaN
# 13            33           1      9  2013    6         NaN
# 14            26           0      9  2013    6         NaN
# 15             5           0      9  2013    6         NaN
# 16            29           1      9  2013    6         NaN
# 17             7           0      9  2013    6         NaN
# 18            42           0      9  2013   12         NaN
# 19             9           0      9  2013   12         NaN
# 20            23           0      9  2013   12         NaN
# 21            50           0      9  2013   12         NaN
# 22            31           0      9  2013   12         NaN
# 23            37           0      9  2013   12         NaN
# 24            50           0      9  2013   12         NaN
# 25             5           0      9  2013   12         NaN
# 26            39           1      9  2013   12         NaN
# 27            27           0      9  2013   12         NaN
# 28            23           0      9  2013   12         NaN
# 29            50           0      9  2013   12         NaN
# 30            16           0      9  2013   12         NaN
# 31            37           1      9  2013   12         NaN
# 32            46           0      9  2013   12         NaN
# 33            13           1      9  2013   19         NaN
# 34             7           1      9  2013   19         NaN
# 35            27           1      9  2013   19         NaN
# 36            33           0      9  2013   19         NaN
# 37            17           0      9  2013   19         NaN
# 38            13           0      9  2013   19         NaN
# 39            13           0      9  2013   19         NaN
# 40            39           1      9  2013   26         NaN
# 41             4           0      9  2013   26         NaN
# 42            16           0      9  2013   26         NaN
# 43             9           0      9  2013   26         NaN
# 44            11           0      9  2013   26         NaN
# 45             1           0      9  2013   26         NaN
#
#             spray_date2                                           JustDate
# 0   2013-07-17 00:00:00  <built-in method date of Timestamp object at 0...
# 1   2013-07-17 00:00:00  <built-in method date of Timestamp object at 0...
# 2   2013-07-17 00:00:00  <built-in method date of Timestamp object at 0...
# 3   2013-07-17 00:00:00  <built-in method date of Timestamp object at 0...
# 4   2013-07-17 00:00:00  <built-in method date of Timestamp object at 0...
# 5   2013-07-17 00:00:00  <built-in method date of Timestamp object at 0...
# 6   2013-07-17 00:00:00  <built-in method date of Timestamp object at 0...
# 7   2013-07-17 00:00:00  <built-in method date of Timestamp object at 0...
# 8   2013-07-17 00:00:00  <built-in method date of Timestamp object at 0...
# 9   2013-07-17 00:00:00  <built-in method date of Timestamp object at 0...
# 10  2013-07-17 00:00:00  <built-in method date of Timestamp object at 0...
# 11  2013-07-17 00:00:00  <built-in method date of Timestamp object at 0...
# 12  2013-07-17 00:00:00  <built-in method date of Timestamp object at 0...
# 13  2013-07-17 00:00:00  <built-in method date of Timestamp object at 0...
# 14  2013-07-17 00:00:00  <built-in method date of Timestamp object at 0...
# 15  2013-07-17 00:00:00  <built-in method date of Timestamp object at 0...
# 16  2013-07-17 00:00:00  <built-in method date of Timestamp object at 0...
# 17  2013-07-17 00:00:00  <built-in method date of Timestamp object at 0...
# 18  2013-07-17 00:00:00  <built-in method date of Timestamp object at 0...
# 19  2013-07-17 00:00:00  <built-in method date of Timestamp object at 0...
# 20  2013-07-17 00:00:00  <built-in method date of Timestamp object at 0...
# 21  2013-07-17 00:00:00  <built-in method date of Timestamp object at 0...
# 22  2013-07-17 00:00:00  <built-in method date of Timestamp object at 0...
# 23  2013-07-17 00:00:00  <built-in method date of Timestamp object at 0...
# 24  2013-07-17 00:00:00  <built-in method date of Timestamp object at 0...
# 25  2013-07-17 00:00:00  <built-in method date of Timestamp object at 0...
# 26  2013-07-17 00:00:00  <built-in method date of Timestamp object at 0...
# 27  2013-07-17 00:00:00  <built-in method date of Timestamp object at 0...
# 28  2013-07-17 00:00:00  <built-in method date of Timestamp object at 0...
# 29  2013-07-17 00:00:00  <built-in method date of Timestamp object at 0...
# 30  2013-07-17 00:00:00  <built-in method date of Timestamp object at 0...
# 31  2013-07-17 00:00:00  <built-in method date of Timestamp object at 0...
# 32  2013-07-17 00:00:00  <built-in method date of Timestamp object at 0...
# 33  2013-07-17 00:00:00  <built-in method date of Timestamp object at 0...
# 34  2013-07-17 00:00:00  <built-in method date of Timestamp object at 0...
# 35  2013-07-17 00:00:00  <built-in method date of Timestamp object at 0...
# 36  2013-07-17 00:00:00  <built-in method date of Timestamp object at 0...
# 37  2013-07-17 00:00:00  <built-in method date of Timestamp object at 0...
# 38  2013-07-17 00:00:00  <built-in method date of Timestamp object at 0...
# 39  2013-07-17 00:00:00  <built-in method date of Timestamp object at 0...
# 40  2013-07-17 00:00:00  <built-in method date of Timestamp object at 0...
# 41  2013-07-17 00:00:00  <built-in method date of Timestamp object at 0...
# 42  2013-07-17 00:00:00  <built-in method date of Timestamp object at 0...
# 43  2013-07-17 00:00:00  <built-in method date of Timestamp object at 0...
# 44  2013-07-17 00:00:00  <built-in method date of Timestamp object at 0...
# 45  2013-07-17 00:00:00  <built-in method date of Timestamp object at 0...

# %%
#df = pd.DataFrame(train.groupby(['Date','Block','Trap','Latitude','Longitude'])['WnvPresent'].sum()).reset_index()
#df['wnv_present_overall'] = np.where(df['WnvPresent'] > 0, 1, 0)
#df.shape
# Out:
# (3480, 12)

# %%
#df.sort_values(['wnv_present_overall', 'Block', 'Trap', "Date"], ascending=False)
# Out:
#            Date  Block  Trap   Latitude  Longitude  WnvPresent  \
# 622  2007-08-07     93  T162  41.725517 -87.614258           1
# 4412 2013-09-06     91  T009  41.992478 -87.862995           1
# 4342 2013-08-29     91  T009  41.992478 -87.862995           3
# 4128 2013-08-08     91  T009  41.992478 -87.862995           1
# 2183 2009-08-25     91  T009  41.992478 -87.862995           1
# 956  2007-08-24     91  T009  41.981964 -87.812827           1
# 739  2007-08-15     91  T009  41.981964 -87.812827           2
# 4197 2013-08-15     90  T226  41.793818 -87.654234           1
# 4127 2013-08-08     90  T226  41.793818 -87.654234           2
# 3911 2013-07-19     90  T226  41.793818 -87.654234           1
# 4340 2013-08-29     89  T159  41.732984 -87.649642           1
# 3838 2013-07-12     89  T159  41.732984 -87.649642           1
# 862  2007-08-22     89  T159  41.732984 -87.649642           2
# 4478 2013-09-12     82  T225  41.743402 -87.731435           1
# 4409 2013-09-06     82  T225  41.743402 -87.731435           1
# 4338 2013-08-29     82  T225  41.743402 -87.731435           1
# 4267 2013-08-22     82  T225  41.743402 -87.731435           1
# 4124 2013-08-08     82  T225  41.743402 -87.731435           1
# 4051 2013-08-01     82  T225  41.743402 -87.731435           2
# 3908 2013-07-19     82  T225  41.743402 -87.731435           1
# 3169 2011-08-26     82  T225  41.743402 -87.731435           1
# 2856 2011-07-25     82  T225  41.743402 -87.731435           1
# 2037 2009-07-31     82  T225  41.743402 -87.731435           1
# 860  2007-08-22     82  T097  41.644612 -87.604498           1
# 971  2007-08-28     81  T107  41.729669 -87.582699           1
# 859  2007-08-22     81  T107  41.729669 -87.582699           1
# 3351 2011-09-16     79  T083  41.754292 -87.590773           1
# 951  2007-08-24     79  T083  41.754292 -87.590773           1
# 834  2007-08-21     79  T015  41.974089 -87.824812           1
# 731  2007-08-15     79  T015  41.974089 -87.824812           1
# ...         ...    ...   ...        ...        ...         ...
# 2364 2009-09-25     10  T030  41.899230 -87.716788           0
# 2302 2009-09-17     10  T030  41.899230 -87.716788           0
# 2246 2009-09-14     10  T030  41.899230 -87.716788           0
# 2040 2009-08-07     10  T030  41.899230 -87.716788           0
# 1986 2009-07-31     10  T030  41.899230 -87.716788           0
# 1931 2009-07-24     10  T030  41.899230 -87.716788           0
# 1868 2009-07-17     10  T030  41.899230 -87.716788           0
# 1810 2009-07-10     10  T030  41.899230 -87.716788           0
# 1755 2009-07-06     10  T030  41.899230 -87.716788           0
# 1701 2009-06-26     10  T030  41.899230 -87.716788           0
# 1647 2009-06-19     10  T030  41.899230 -87.716788           0
# 1593 2009-06-12     10  T030  41.899230 -87.716788           0
# 1550 2009-06-05     10  T030  41.899230 -87.716788           0
# 1500 2009-06-02     10  T030  41.899230 -87.716788           0
# 1459 2009-05-28     10  T030  41.899230 -87.716788           0
# 1354 2007-10-04     10  T030  41.899230 -87.716788           0
# 1260 2007-09-24     10  T030  41.899230 -87.716788           0
# 1155 2007-09-18     10  T030  41.899230 -87.716788           0
# 1071 2007-09-12     10  T030  41.899230 -87.716788           0
# 972  2007-09-04     10  T030  41.899230 -87.716788           0
# 866  2007-08-24     10  T030  41.899230 -87.716788           0
# 754  2007-08-21     10  T030  41.899230 -87.716788           0
# 637  2007-08-15     10  T030  41.899230 -87.716788           0
# 537  2007-08-07     10  T030  41.899230 -87.716788           0
# 398  2007-08-01     10  T030  41.899230 -87.716788           0
# 347  2007-07-27     10  T030  41.899230 -87.716788           0
# 261  2007-07-18     10  T030  41.899230 -87.716788           0
# 186  2007-07-11     10  T030  41.899230 -87.716788           0
# 138  2007-07-02     10  T030  41.899230 -87.716788           0
# 103  2007-06-29     10  T030  41.899230 -87.716788           0
#
#       wnv_present_overall
# 622                     1
# 4412                    1
# 4342                    1
# 4128                    1
# 2183                    1
# 956                     1
# 739                     1
# 4197                    1
# 4127                    1
# 3911                    1
# 4340                    1
# 3838                    1
# 862                     1
# 4478                    1
# 4409                    1
# 4338                    1
# 4267                    1
# 4124                    1
# 4051                    1
# 3908                    1
# 3169                    1
# 2856                    1
# 2037                    1
# 860                     1
# 971                     1
# 859                     1
# 3351                    1
# 951                     1
# 834                     1
# 731                     1
# ...                   ...
# 2364                    0
# 2302                    0
# 2246                    0
# 2040                    0
# 1986                    0
# 1931                    0
# 1868                    0
# 1810                    0
# 1755                    0
# 1701                    0
# 1647                    0
# 1593                    0
# 1550                    0
# 1500                    0
# 1459                    0
# 1354                    0
# 1260                    0
# 1155                    0
# 1071                    0
# 972                     0
# 866                     0
# 754                     0
# 637                     0
# 537                     0
# 398                     0
# 347                     0
# 261                     0
# 186                     0
# 138                     0
# 103                     0
#
# [4616 rows x 7 columns]

# %% [markdown]
# ### Joiniing spray data to mosquito test data

# %% [markdown]
# The spray location coordinates will not match the trap coordinates exactly so we will find the nearest spray location. Note provided spray data is limited to 2013 and 2011 and the data for 2011 is very limited.  To find the nearest spray location for a trap...
# - Take the mosquito test year and date to determine appropriate spray data
# - Find the distance from each spray location to the trap location
# - Finally take the smallest distance and assume that spray location is the nearest to the trap

# %%
# mask = (df['date'] > start_date) & (df['date'] <= end_date)

import datetime

def find_spray_datetime(x):
    location = [x.Latitude, x.Longitude]
    distances = []
    spray_info = []
    # get spray observations for given year AND date/time prior to mosquito test
    df = pd.DataFrame(df_spray[(df_spray['Date'] < x.Date) & (df_spray['Year'] == x.Year)]).reset_index()
    # iterate through resulting set and grab distance in miles, date and lat and long as well
    if df.shape[0] > 0:
        for index, row in df.iterrows():
            dict = {}
            spray_location = [row.Latitude, row.Longitude]
            # get distance between trap and spray location
            distance = vincenty(location, spray_location).miles
            distance = str(round(distance, 6))
            distances.append(distance)
            dict['distance'] = distance
            dict['spray_info'] = '|'.join([row['Date'].strftime('%Y-%m-%d'), distance, str(row.Latitude), str(row.Longitude)])
            spray_info.append(dict)
            
        # sort distances
        distances.sort(reverse=False)
        #print(distances)
        shortest_distance = distances.pop(0)
        for d in spray_info:
            if shortest_distance == d['distance']:
                info = d['spray_info']
                break
        return info
    else:
        # return none if no valid spray info for mosquito test date
        return 'none'

# %%
# only call the find spray time if year is 2011 or 2013 and month is after July.  
# Spray data does not exist for other times
train['spray_info'] = train[(train['Year'] >= 2011) & (train['Month'] >= 7)].apply(lambda x: find_spray_datetime(x), axis=1)

# %%
#train['spray_info'].value_counts()
# Out:
# none                                                         1434
# 2013-07-17|1.016937|41.9728533333333|-87.8710233333333        170
# 2011-09-07|2.784849|41.9757483333333|-87.83655999999999        39
# 2013-07-17|10.002319|42.011858333333294|-87.784405             36
# 2013-07-17|0.03972|42.0084983333333|-87.77719                  33
# 2011-08-29|30.930854|42.390395|-88.08831500000001              25
# 2013-07-17|10.000144|41.723381666666704|-87.656675             25
# 2013-07-17|0.009117|41.7331116666667|-87.6495966666667         25
# 2013-07-17|0.970296|41.99808|-87.7637166666667                 24
# 2013-07-17|10.000037|41.722215000000006|-87.6529733333333      22
# 2013-07-17|0.270572|41.99799|-87.768085                        20
# 2013-07-17|10.00371|42.0050183333333|-87.7745716666667         20
# 2013-07-17|0.168923|41.7211583333333|-87.6627733333333         20
# 2013-07-17|1.385875|41.973141666666706|-87.8702516666667       20
# 2013-07-25|0.00201|41.9518783333333|-87.72502166666669         19
# 2013-07-17|0.038746|41.72347|-87.6506233333333                 19
# 2013-07-17|0.987259|42.01144|-87.7882116666667                 19
# 2013-07-17|11.136433|41.743058333333295|-87.66252              18
# 2013-08-08|0.781923|41.9179233333333|-87.7000933333333         17
# 2013-07-25|1.17117|41.9678866666667|-87.72680333333331         17
# 2013-07-17|1.492798|41.7324366666667|-87.629355                17
# 2013-07-25|10.00129|41.9630116666667|-87.7139633333333         16
# 2013-07-25|0.954018|41.9605266666667|-87.7398                  16
# 2013-07-17|16.260121|41.743058333333295|-87.66252              16
# 2011-08-29|30.433944|42.390395|-88.08831500000001              16
# 2013-07-17|10.000217|41.7338916666667|-87.6484833333333        15
# 2013-08-15|0.158928|41.952391666666706|-87.8011816666667       14
# 2013-07-17|10.55775|41.97271|-87.87015                         14
2013-07-17|1.016937|41.9728533333333|-87.87102...
# 10387  2013-07-17|1.016937|41.9728533333333|-87.87102...
# 10388  2013-07-17|1.016937|41.9728533333333|-87.87102...
# 10389  2013-07-17|1.016937|41.9728533333333|-87.87102...
# 10390  2013-07-17|1.016937|41.9728533333333|-87.87102...
# 10391  2013-07-17|1.016937|41.9728533333333|-87.87102...
# 10392  2013-07-17|1.016937|41.9728533333333|-87.87102...
# 10338     2013-07-17|0.970296|41.99808|-87.7637166666667
# 10412            2013-07-17|0.270572|41.99799|-87.768085
# 10312  2013-07-17|0.168923|41.7211583333333|-87.66277...
#
# [200 rows x 5 columns]

# %%
# push to csv file
#train.sort_values('spray_info', ascending=True).to_csv('train_w_spray.csv')

# %% [markdown]
# ** Group the training data by Year, Month, Trap and Species and determing if WNV is present for that group **

# %%
df_train = pd.DataFrame(train.groupby(['Year','Month','Species', 'Block','Trap', 'Street','Latitude', 'Longitude']).agg({'NumMosquitos':'sum','WnvPresent': 'sum', 'Date': 'size'})).reset_index()
 #['WnvPresent'].sum()).reset_index()
df_train['WnvPresentForGroup'] = np.where(df_train['WnvPresent'] > 0, 1, 0)
print(df_train.shape)
df_train.columns = ['Year','Month','Species', 'Block','Trap', 'Street','Latitude', 'Longitude', 'SumNumMosquitos', 'SumWnvPresent', 'GroupCount', 'WnvPresentForGroup']
df_train.sort_values(['Year','Month','Trap', 'WnvPresentForGroup'], ascending=False).head(5)
# Out:
# (3480, 12)
#       Year  Month                 Species  Block  Trap            Street  \
# 3310  2013      9           CULEX PIPIENS     10  T903           W OHARE
# 3381  2013      9  CULEX PIPIENS/RESTUANS     10  T903           W OHARE
# 3309  2013      9           CULEX PIPIENS     10  T900   W OHARE AIRPORT
# 3380  2013      9  CULEX PIPIENS/RESTUANS     10  T900   W OHARE AIRPORT
# 3451  2013      9          CULEX RESTUANS     10  T900   W OHARE AIRPORT
#
#        Latitude  Longitude  SumNumMosquitos  SumWnvPresent  GroupCount  \
# 3310  41.957799 -87.930995               20              0           1
# 3381  41.957799 -87.930995               10              0           1
# 3309  41.974689 -87.890615              546              5          23
# 3380  41.974689 -87.890615              640              9          19
# 3451  41.974689 -87.890615               45              1           3
#
#       WnvPresentForGroup
# 3310                   0
# 3381                   0
# 3309                   1
# 3380                   1
# 3451                   1

# %%
#  Keep has reference to timedelta

#(df['date'] > start_date) & (df['date'] <= end_date)
#import datetime
#spray['DatePlus15'] = spray['Date'].apply(lambda x: x + datetime.timedelta(days=15))
#end_date = date_1 + datetime.timedelta(days=10)

# %% [markdown]
# ### Weather Data

# %% [markdown]
# ** _It is believed that hot and dry conditions are more favorable for West Nile virus than cold and wet. We provide you with the dataset from NOAA of the weather conditions of 2007 to 2014, during the months of the tests._**
#
# Based on the above comment from Kaggle, will focus on **Heating** and **Cooling** days and **Total Precipitation**
#
# Link to NOAA doc that explains heating and cooling days
# http://www.cpc.ncep.noaa.gov/products/analysis_monitoring/cdus/degree_days/ddayexp.shtml

# %%
print(weather.shape)
weather.head()
# Out:
# (2944, 22)
# (2931, 22)

# %%
weather.info() 
# No nulls, but will have to change column types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2944 entries, 0 to 2943
# Data columns (total 22 columns):
# Station        2944 non-null int64
# Date           2944 non-null object
# Tmax           2944 non-null int64
# Tmin           2944 non-null int64
# Tavg           2944 non-null object
# Depart         2944 non-null object
# DewPoint       2944 non-null int64
# WetBulb        2944 non-null object
# Heat           2944 non-null object
# Cool           2944 non-null object
# Sunrise        2944 non-null object
# Sunset         2944 non-null object
# CodeSum        2944 non-null object
# Depth          2944 non-null object
# Water1         2944 non-null object
# SnowFall       2944 non-null object
# PrecipTotal    2944 non-null object
# StnPressure    2944 non-null object
# SeaLevel       2944 non-null object
# ResultSpeed    2944 non-null float64
# ResultDir      2944 non-null int64
# AvgSpeed       2944 non-null object
# dtypes: float64(1), int64(5), object(16)
# memory usage: 506.1+ KB

# %%
# Drop rows that have an M (missing data)
df_weather = weather[(weather.Cool != 'M') & (weather.Heat != 'M') & (weather.PrecipTotal != 'M')]
print(df_weather.shape)

# %%
# Drop rows where precip == T
df_weather = df_weather[df_weather.PrecipTotal.str.replace(' ', '') != 'T']
print(df_weather.shape)
# Out:
# (2614, 22)

# %%
df_weather['Cool'] = df_weather['Cool'].astype('int')
df_weather['Heat'] = df_weather['Heat'].astype('int')
df_weather['PrecipTotal'] = df_weather['PrecipTotal'].astype('float')

# %%
df_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2614 entries, 0 to 2943
# Data columns (total 22 columns):
# Station        2614 non-null int64
# Date           2614 non-null object
# Tmax           2614 non-null int64
# Tmin           2614 non-null int64
# Tavg           2614 non-null object
# Depart         2614 non-null object
# DewPoint       2614 non-null int64
# WetBulb        2614 non-null object
# Heat           2614 non-null int64
# Cool           2614 non-null int64
# Sunrise        2614 non-null object
# Sunset         2614 non-null object
# CodeSum        2614 non-null object
# Depth          2614 non-null object
# Water1         2614 non-null object
# SnowFall       2614 non-null object
# PrecipTotal    2614 non-null float64
# StnPressure    2614 non-null object
# SeaLevel       2614 non-null object
# ResultSpeed    2614 non-null float64
# ResultDir      2614 non-null int64
# AvgSpeed       2614 non-null object
# dtypes: float64(2), int64(7), object(13)
# memory usage: 469.7+ KB

# %% [markdown]
# ** Considered just grabbing data for Station 1, but better to get average of Station data since some records are removed due to Missing and Trace values **

# %%
#df_weather1 = df_weather[['Date','Heat', 'Cool', 'PrecipTotal']][df_weather['Station'] == 1]
#df_weather1.head(31)
# Out:
#           Date  Heat  Cool  PrecipTotal
# 0   2007-05-01     0     2         0.00
# 2   2007-05-02    14     0         0.00
# 4   2007-05-03     9     0         0.00
# 10  2007-05-06     6     0         0.00
# 14  2007-05-08     0     3         0.00
# 16  2007-05-09     0     4         0.13
# 18  2007-05-10     0     5         0.00
# 20  2007-05-11     4     0         0.00
# 22  2007-05-12    10     0         0.00
# 24  2007-05-13     9     0         0.00
# 26  2007-05-14     0     8         0.00
# 28  2007-05-15     0     4         0.38
# 30  2007-05-16    10     0         0.14
# 32  2007-05-17    12     0         0.00
# 34  2007-05-18     8     0         0.00
# 36  2007-05-19     0     3         0.00
# 38  2007-05-20     9     0         0.07
# 40  2007-05-21     3     0         0.00
# 42  2007-05-22     0     6         0.00
# 44  2007-05-23     0    10         0.00
# 46  2007-05-24     0    11         0.02
# 50  2007-05-26     8     0         1.01
# 52  2007-05-27     0     1         0.04
# 56  2007-05-29     0     9         0.00
# 58  2007-05-30     0    12         0.00
# 60  2007-05-31     0     7         0.01
# 62  2007-06-01     0     9         0.19
# 64  2007-06-02     0     8         0.04
# 66  2007-06-03     0     5         0.01
# 68  2007-06-04     0     0         0.39
# 70  2007-06-05     9     0         0.42

# %% [markdown]
# ** Better to get average of Station 1 and Station 2 **

# %%
df_weather2 = pd.DataFrame(df_weather.groupby(['Date']).agg({'Heat': 'mean', 'Cool': 'mean', 'PrecipTotal': 'mean'})).reset_index()

# %%
# We can round later
#df_weather2['Heat'] = round(df_weather2['Heat'])
#df_weather2['Cool'] = round(df_weather2['Cool'])

# %%
df_weather2['Date'] = pd.to_datetime(df_weather2['Date'])
df_weather2['Year'] = df_weather2['Date'].apply(lambda x: x.year)
df_weather2['Month'] = df_weather2['Date'].apply(lambda x: x.month)
df_weather2['Day'] = df_weather2['Date'].apply(lambda x: x.day)

# %%
df_weather3 = pd.DataFrame(df_weather2.groupby(['Year', 'Month']).agg({'Heat': 'mean', 'Cool': 'mean', 'PrecipTotal': 'mean'})).reset_index()
print(df_weather3.shape)
df_weather3['Heat'] = round(df_weather3['Heat'])
df_weather3['Cool'] = round(df_weather3['Cool'])
df_weather3['Heat'] = df_weather3['Heat'].astype('int')
df_weather3['Cool'] = df_weather3['Cool'].astype('int')
df_weather3.sort_values(['PrecipTotal'], ascending=False)
# Out:
# (48, 5)
#     Year  Month  Heat  Cool  PrecipTotal
# 10  2008      9     1     3     0.382333
# 20  2010      7     0    14     0.331897
# 3   2007      8     0    10     0.306667
# 45  2014      8     0    10     0.275645
# 43  2014      6     0     7     0.250345
# 26  2011      7     0    15     0.247500
# 19  2010      6     0     7     0.247500
# 13  2009      6     2     6     0.229821
# 24  2011      5     8     2     0.229815
# 17  2009     10    15     0     0.208548
# 18  2010      5     6     3     0.180357
# 37  2013      6     1     6     0.179833
# 36  2013      5     6     3     0.179167
# 42  2014      5     6     3     0.167857
# 25  2011      6     1     6     0.166000
# 41  2013     10    11     1     0.148214
# 8   2008      7     0    10     0.146667
# 33  2012      8     0     9     0.140333
# 7   2008      6     0     7     0.137069
# 27  2011      8     0     9     0.136333
# 12  2009      5     5     1     0.135172
# 15  2009      8     1     7     0.134355
# 6   2008      5     9     0     0.133500
# 32  2012      7     0    17     0.124000
# 44  2014      7     0     7     0.123000
# 30  2012      5     3     4     0.121935
# 28  2011      9     5     3     0.113103
# 2   2007      7     0     9     0.112419
# 46  2014      9     3     4     0.103333
# 47  2014     10    12     0     0.103000
# 35  2012     10    12     0     0.099500
# 21  2010      8     0    12     0.097931
# 1   2007      6     1     7     0.096786
# 22  2010      9     2     3     0.086852
# 11  2008     10    12     1     0.083750
# 9   2008      8     0     8     0.079828
# 40  2013      9     2     5     0.078276
# 39  2013      8     0     9     0.077500
# 38  2013      7     0    10     0.071429
# 29  2011     10    10     1     0.070000
# 14  2009      7     0     6     0.068667
# 0   2007      5     3     3     0.063621
# 34  2012      9     3     3     0.060500
# 5   2007     10     7     2     0.058621
# 23  2010     10     9     1     0.051833
# 4   2007      9     2     6     0.045000
# 16  2009      9     2     3     0.035517
# 31  2012      6     0    10     0.033276

# %%
df_weather3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 5 columns):
# Year           48 non-null int64
# Month          48 non-null int64
# Heat           48 non-null int64
# Cool           48 non-null int64
# PrecipTotal    48 non-null float64
# dtypes: float64(1), int64(4)
# memory usage: 2.0 KB

# %%
df_weather3.head()
# Out:
#    Year  Month  Heat  Cool  PrecipTotal
# 0  2007      5     3     3     0.063621
# 1  2007      6     1     7     0.096786
# 2  2007      7     0     9     0.112419
# 3  2007      8     0    10     0.306667
# 4  2007      9     2     6     0.045000

# %%
df_weather3[(df_weather3['Year'] == 2007) & (df_weather3['Month'] == 7) ]
# Out:
#    Year  Month  Heat  Cool  PrecipTotal
# 2  2007      7   0.0   9.0     0.112419

# %%
df_weather3.sort_values('PrecipTotal', ascending=False)
# Out:
#     Year  Month  Heat  Cool  PrecipTotal
# 10  2008      9   1.0   3.0     0.382333
# 20  2010      7   0.0  14.0     0.331897
# 3   2007      8   0.0  10.0     0.306667
# 45  2014      8   0.0  10.0     0.275645
# 43  2014      6   0.0   7.0     0.250345
# 26  2011      7   0.0  15.0     0.247500
# 19  2010      6   0.0   7.0     0.247500
# 13  2009      6   2.0   6.0     0.229821
# 24  2011      5   8.0   2.0     0.229815
# 17  2009     10  15.0   0.0     0.208548
# 18  2010      5   6.0   3.0     0.180357
# 37  2013      6   1.0   6.0     0.179833
# 36  2013      5   6.0   3.0     0.179167
# 42  2014      5   6.0   3.0     0.167857
# 25  2011      6   1.0   6.0     0.166000
# 41  2013     10  11.0   1.0     0.148214
# 8   2008      7   0.0  10.0     0.146667
# 33  2012      8   0.0   9.0     0.140333
# 7   2008      6   0.0   7.0     0.137069
# 27  2011      8   0.0   9.0     0.136333
# 12  2009      5   5.0   1.0     0.135172
# 15  2009      8   1.0   7.0     0.134355
# 6   2008      5   9.0   0.0     0.133500
# 32  2012      7   0.0  17.0     0.124000
# 44  2014      7   0.0   7.0     0.123000
# 30  2012      5   3.0   4.0     0.121935
# 28  2011      9   5.0   3.0     0.113103
# 2   2007      7   0.0   9.0     0.112419
# 46  2014      9   3.0   4.0     0.103333
# 47  2014     10  12.0   0.0     0.103000
# 35  2012     10  12.0   0.0     0.099500
# 21  2010      8   0.0  12.0     0.097931
# 1   2007      6   1.0   7.0     0.096786
# 22  2010      9   2.0   3.0     0.086852
# 11  2008     10  12.0   1.0     0.083750
# 9   2008      8   0.0   8.0     0.079828
# 40  2013      9   2.0   5.0     0.078276
# 39  2013      8   0.0   9.0     0.077500
# 38  2013      7   0.0  10.0     0.071429
# 29  2011     10  10.0   1.0     0.070000
# 14  2009      7   0.0   6.0     0.068667
# 0   2007      5   3.0   3.0     0.063621
# 34  2012      9   3.0   3.0     0.060500
# 5   2007     10   7.0   2.0     0.058621
# 23  2010     10   9.0   1.0     0.051833
# 4   2007      9   2.0   6.0     0.045000
# 16  2009      9   2.0   3.0     0.035517
# 31  2012      6   0.0  10.0     0.033276

# %%
df_weather3.sort_values('Heat', ascending=False).head()
# Out:
#     Year  Month  Heat  Cool  PrecipTotal
# 17  2009     10    15     0     0.208548
# 47  2014     10    12     0     0.103000
# 11  2008     10    12     1     0.083750
# 35  2012     10    12     0     0.099500
# 41  2013     10    11     1     0.148214

# %% [markdown]
# ### Join monthly weather averages to mosquito test data

# %% [markdown]
# **The following method is a quick way to append month averages to the mosquito test data.
# The three values in the delimited string will ultimately need to be in separate columns**

# %%
def add_weather_data(row):
    df3 = df_weather3[(df_weather3['Year'] == row['Year']) & (df_weather3['Month'] == row['Month'])]
    precip = str(round(df3['PrecipTotal'].values[0], 4))
    heat = str(df3['Heat'].values[0])
    cool = str(df3['Cool'].values[0])
    return '|'.join([heat, cool, precip])

# %%
df_train['Weather_Info'] = df_train.apply(lambda x: add_weather_data(x), axis=1 )

# %%
df_train[['Year', 'Month', 'Trap','Weather_Info']].head(20)
# Out:
#     Year  Month  Trap Weather_Info
# 0   2007      5  T096   3|3|0.0636
# 1   2007      5  T048   3|3|0.0636
# 2   2007      5  T050   3|3|0.0636
# 3   2007      5  T054   3|3|0.0636
# 4   2007      5  T086   3|3|0.0636
# 5   2007      5  T002   3|3|0.0636
# 6   2007      5  T129   3|3|0.0636
# 7   2007      5  T143   3|3|0.0636
# 8   2007      5  T148   3|3|0.0636
# 9   2007      5  T015   3|3|0.0636
# 10  2007      5  T048   3|3|0.0636
# 11  2007      5  T049   3|3|0.0636
# 12  2007      5  T091   3|3|0.0636
# 13  2007      5  T045   3|3|0.0636
# 14  2007      5  T153   3|3|0.0636
# 15  2007      5  T094   3|3|0.0636
# 16  2007      5  T054   3|3|0.0636
# 17  2007      5  T086   3|3|0.0636
# 18  2007      5  T096   3|3|0.0636
# 19  2007      5  T046   3|3|0.0636

# %%
def get_heat(x):
    values = x.split('|')
    return values[0]

def get_cool(x):
    values = x.split('|')
    return values[1]

def get_precip(x):
    values = x.split('|')
    return values[2]

# %%
df_train['HeatMonthAvg'] = df_train['Weather_Info'].apply(get_heat)

# %%
df_train['CoolMonthAvg'] = df_train['Weather_Info'].apply(get_cool)
df_train['PrecipMonthAvg'] = df_train['Weather_Info'].apply(get_precip)

# %%
df_train[['Year', 'Month', 'Trap','HeatMonthAvg','CoolMonthAvg','PrecipMonthAvg']].head(20)
# Out:
#     Year  Month  Trap HeatMonthAvg CoolMonthAvg PrecipMonthAvg
# 0   2007      5  T096            3            3         0.0636
# 1   2007      5  T048            3            3         0.0636
# 2   2007      5  T050            3            3         0.0636
# 3   2007      5  T054            3            3         0.0636
# 4   2007      5  T086            3            3         0.0636
# 5   2007      5  T002            3            3         0.0636
# 6   2007      5  T129            3            3         0.0636
# 7   2007      5  T143            3            3         0.0636
# 8   2007      5  T148            3            3         0.0636
# 9   2007      5  T015            3            3         0.0636
# 10  2007      5  T048            3            3         0.0636
# 11  2007      5  T049            3            3         0.0636
# 12  2007      5  T091            3            3         0.0636
# 13  2007      5  T045            3            3         0.0636
# 14  2007      5  T153            3            3         0.0636
# 15  2007      5  T094            3            3         0.0636
# 16  2007      5  T054            3            3         0.0636
# 17  2007      5  T086            3            3         0.0636
# 18  2007      5  T096            3            3         0.0636
# 19  2007      5  T046            3            3         0.0636
